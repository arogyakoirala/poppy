# %%
import pandas as pd

best_dates = pd.read_csv("/data/tmp/arogya/afg_updated/inputs/best_dates.csv")
best_dates.head()
# Out:
#    Unnamed: 0   Latitude  Longitude Best Start Date 2014 Best End Date 2014  \
# 0           0  36.742867  72.257067           2014-03-22         2014-04-06
# 1           1  36.742867  72.259873           2014-03-22         2014-04-06
# 2           2  36.742867  72.262678           2014-02-18         2014-03-05
# 3           3  36.742867  72.265484           2014-02-18         2014-03-05
# 4           4  36.742867  72.268290           2014-02-18         2014-03-05
#
#    Peak NDVI 2014 Best Start Date 2015 Best End Date 2015  Peak NDVI 2015  \
# 0         -0.0017           2015-02-18         2015-03-05         -0.0159
# 1         -0.0080           2015-02-18         2015-03-05         -0.0159
# 2         -0.0050           2015-01-17         2015-02-01         -0.0135
# 3         -0.0224           2015-03-22         2015-04-06         -0.0254
# 4         -0.0235           2015-02-18         2015-03-05         -0.0261
#
# ...

# %%
import os
dir = "/data/afg_satellite/bestdates/pixel_maxdata_real_June_21_22"
filenames = [file for file in os.listdir(dir)]
dataframes = []
for filename in filenames:
    dataframes.append(pd.read_csv(f"{dir}/{filename}"))

data_concatenated = pd.concat(dataframes, axis=0)
data_concatenated.head()
# Out:
#     Latitude  Longitude Best Start Date 2021 Best End Date 2021  \
# 0  36.742867  72.257067           2021-03-06         2021-03-21
# 1  36.742867  72.259873           2021-03-06         2021-03-21
# 2  36.742867  72.262678           2021-03-06         2021-03-21
# 3  36.742867  72.265484           2021-05-09         2021-05-24
# 4  36.742867  72.268290           2021-05-09         2021-05-24
#
#    Peak NDVI 2021 Best Start Date 2022 Best End Date 2022  Peak NDVI 2022
# 0         -0.0322           2022-03-06         2022-03-21         -0.0166
# 1         -0.0063           2022-03-06         2022-03-21         -0.0187
# 2         -0.0155           2022-01-01         2022-01-16         -0.0154
# 3         -0.0269           2022-03-06         2022-03-21         -0.0187
# 4         -0.0340           2022-03-06         2022-03-21         -0.0222

# %%
best_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11559908 entries, 0 to 11559907
# Data columns (total 24 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0            int64
#  1   Latitude              float64
#  2   Longitude             float64
#  3   Best Start Date 2014  object
#  4   Best End Date 2014    object
#  5   Peak NDVI 2014        float64
#  6   Best Start Date 2015  object
#  7   Best End Date 2015    object
#  8   Peak NDVI 2015        float64
#  9   Best Start Date 2016  object
#  10  Best End Date 2016    object
#  11  Peak NDVI 2016        float64
#  12  Best Start Date 2017  object
#  13  Best End Date 2017    object
#  14  Peak NDVI 2017        float64
#  15  Best Start Date 2018  object
#  16  Best End Date 2018    object
#  17  Peak NDVI 2018        float64
#  18  Best Start Date 2019  object
#  19  Best End Date 2019    object
#  20  Peak NDVI 2019        float64
#  21  Best Start Date 2020  object
# ...

# %%
data_concatenated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11559908 entries, 0 to 9872
# Data columns (total 8 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Latitude              float64
#  1   Longitude             float64
#  2   Best Start Date 2021  object
#  3   Best End Date 2021    object
#  4   Peak NDVI 2021        float64
#  5   Best Start Date 2022  object
#  6   Best End Date 2022    object
#  7   Peak NDVI 2022        float64
# dtypes: float64(4), object(4)
# memory usage: 793.8+ MB

# %%
data_concatenated.to_csv("/data/tmp/arogya/afg_2021/inputs/best_dates.csv")
data_concatenated.to_csv("/data/tmp/arogya/afg_2022/inputs/best_dates.csv")
