# %%
import os

DATA_DIR="/data/tmp/arogya/tmp"
DNQ_DIR=f"{DATA_DIR}/interim/dnq"

folders = sorted([d for d in os.listdir(DNQ_DIR) if ".gpkg" not in d])
folders
# Out:
# ['0',
#  '1',
#  '10',
#  '100',
#  '1000',
#  '1001',
#  '1002',
#  '1003',
#  '1004',
#  '1005',
#  '1006',
#  '1007',
#  '1008',
#  '1009',
#  '101',
#  '1010',
#  '1011',
#  '1012',
#  '1013',
#  '1014',
#  '1015',
#  '1016',
#  '1017',
#  '1018',
#  '1019',
#  '102',
#  '1020',
#  '1021',
#  '1022',
#  '1023',
#  '1024',
#  '1025',
#  '1026',
#  '1027',
#  '1028',
#  '1029',
#  '103',
#  '1030',
#  '1031',
#  '1032',
#  '1033',
#  '1034',
#  '1035',
#  '1036',
#  '1037',
#  '1038',
#  '1039',
#  '104',
#  '1040',
#  '1041',
#  '1042',
#  '1043',
#  '1044',
#  '1045',
#  '1046',
#  '1047',
#  '1048',
#  '1049',
#  '105',
#  '1050',
#  '1051',
#  '1052',
#  '1053',
#  '1054',
#  '1055',
#  '1056',
#  '1057',
#  '1058',
#  '1059',
#  '106',
#  '1060',
#  '1061',
#  '1062',
#  '1063',
#  '1064',
#  '1065',
#  '1066',
#  '1067',
#  '1068',
#  '1069',
#  '107',
#  '1070',
#  '1071',
#  '1072',
#  '1073',
#  '1074',
#  '1075',
#  '1076',
#  '1077',
#  '1078',
#  '1079',
#  '108',
# ...

# %%
successfull = "but moving on.."

# %%
def check(i):
    d = folders[i]
    f = f"{DNQ_DIR}/{d}/log.txt"
    with open(f, 'r') as f2:
        if 'but moving' in f2.read():
            return True
        return False

# %%
count=0
missing=[]
i_s = []
for i in range(1150):
    if check(i):
        count+=1
        missing.append(folders[i])
        i_s.append(i)

# %%
count
# Out:
# 53

# %%
missing
# Out:
# ['1022',
#  '1080',
#  '1081',
#  '1084',
#  '1087',
#  '1091',
#  '1095',
#  '1096',
#  '1097',
#  '1099',
#  '1100',
#  '1103',
#  '1113',
#  '1114',
#  '1119',
#  '1120',
#  '1124',
#  '1129',
#  '1134',
#  '1143',
#  '1144',
#  '1145',
#  '1146',
#  '115',
#  '1150',
#  '117',
#  '121',
#  '135',
#  '235',
#  '314',
#  '433',
#  '579',
#  '610',
#  '613',
#  '615',
#  '616',
#  '617',
#  '618',
#  '619',
#  '62',
#  '620',
#  '622',
#  '624',
#  '625',
#  '626',
#  '627',
#  '628',
#  '676',
#  '705',
#  '734',
#  '893',
#  '918',
#  '998']

# %%
i_s
# Out:
# [28,
#  92,
#  93,
#  96,
#  99,
#  104,
#  108,
#  109,
#  110,
#  112,
#  115,
#  118,
#  129,
#  130,
#  135,
#  137,
#  141,
#  146,
#  152,
#  162,
#  163,
#  164,
#  165,
#  169,
#  170,
#  172,
#  177,
#  192,
#  303,
#  391,
#  523,
#  684,
#  720,
#  723,
#  725,
#  726,
#  727,
#  728,
#  729,
#  730,
#  731,
#  733,
#  735,
#  736,
#  737,
#  738,
#  739,
#  792,
#  825,
#  857,
#  1033,
#  1061,
#  1149]

# %%
import geopandas as gpd
# Out:
# /home/arogya/.local/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
grid = gpd.read_file("/data/tmp/arogya/tmp/interim/grid.gpkg")
aoi = gpd.read_file("/data/tmp/arogya/tmp/inputs/2305.gpkg")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1,figsize=(10,10), dpi=100)
grid.boundary.plot(ax=ax)
grid[grid['grid_id'].astype(str).isin(missing)].plot(ax=ax)
aoi.boundary.plot(ax=ax, color='red')
# Out:
# <AxesSubplot:>

# %%
grid[grid['grid_id'].astype(str).isin(missing)]
# Out:
#       grid_id  ID_0  ISO   NAME_ENGLI     NAME_ISO     NAME_FAO   NAME_LOCAL  \
# 62         62     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 115       115     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 117       117     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 121       121     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 135       135     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 235       235     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 314       314     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 433       433     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 579       579     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 610       610     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# 613       613     1  AFG  Afghanistan  AFGHANISTAN  Afghanistan  Afghanestan
# ...
