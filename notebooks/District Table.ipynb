# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
districts = gpd.read_file("../../../poppy/data/district398/")
districts.head()
# Out:
#    OBJECTID PROV_34_NA    DIST_34_NA  DISTID  PROVID  \
# 0         1      Hirat        Gulran    2007      20
# 1         2      Hirat         Koshk    2006      20
# 2         3      Hirat  Koshki Kohna    2016      20
# 3         4      Hirat        Kohsan    2008      20
# 4         5      Hirat       Ghoryan    2009      20
#
#                                             geometry
# 0  POLYGON ((61.13156 35.11849, 61.13137 35.11949...
# 1  POLYGON ((62.00758 35.44605, 62.02049 35.44333...
# 2  POLYGON ((62.47754 35.27873, 62.47791 35.27881...
# 3  POLYGON ((61.60531 34.88130, 61.60174 34.87717...
# 4  POLYGON ((61.75743 34.65122, 61.75567 34.64950...

# %%
districts[districts['PROV_34_NA']=='Kandahar']
# Out:
#      OBJECTID PROV_34_NA     DIST_34_NA  DISTID  PROVID  \
# 40         41   Kandahar       Registan    2409      24
# 41         42   Kandahar       Shorabak    2410      24
# 42         43   Kandahar    Spin Boldak    2411      24
# 43         44   Kandahar      Arghistan    2412      24
# 44         45   Kandahar       Panjwayi    2408      24
# 45         46   Kandahar       Kandahar    2401      24
# 46         47   Kandahar          Daman    2402      24
# 47         48   Kandahar  Shah Wali Kot    2403      24
# 48         49   Kandahar      Arghandab    2404      24
# 49         50   Kandahar        Maywand    2407      24
# 50         51   Kandahar         Ghorak    2406      24
# 51         52   Kandahar          Zhari    2416      24
# 52         53   Kandahar        Khakrez    2405      24
# 58         59   Kandahar           Nesh    2415      24
# 111       113   Kandahar    Miya Nishin    2414      24
# 397       400   Kandahar          Maruf    2413      24
#
# ...
